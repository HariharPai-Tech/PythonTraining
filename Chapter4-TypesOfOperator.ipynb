# %% [markdown]
# 1. Arithemetic Operators
# 2. Relational Operators
# 3. Assignment Operators
# 4. Logical Operators
# 5. Bitwise Operators
# 6. Membership Operators
# 7. Identity Operators

# %% [markdown]
# ### Arithematic Operator

# %% [markdown]
# ![Arithematic.png](./Images/Arithematic.png)

# %%
# exponent example
<exponent example>
# Out:
#   File "<ipython-input-1-5da5e1424826>", line 2
#     <exponent example>
#     ^
# SyntaxError: invalid syntax

# %%
#floor example
<floor example>

# %%
# What will be the answer

<minus value divided>

# %% [markdown]
# ### Relational

# %% [markdown]
# ![Relational.png](./Images/Relational.png)

# %%
if('SAP' == 'SAP'):
    print ("First, Both matches")
     
if('SAP' == 'sap'):
    print ("Second, Both SAP matches")
     
if ('SAP' == 'sap'.upper()):
    print ("Third, Both SAP match")
# Out:
# First, Both matches
# Third, Both SAP match

# %% [markdown]
# ### Membership Operators

# %% [markdown]
# ![Membership.png](./Images/Membership.png)

# %% [markdown]
# ![tapWater.jpeg](attachment:tapWater.jpeg)

# %%
# test for membership in a sequence, such as strings, lists, or tuples
 
mulcipalityWaterDays =["Monday","Wednesday","Saturday"]
 
whichDay=input("Enter the day of week")
 
if (<check if water will come today> ) :
    print ("Yaayyy today municipal water will come you can have a bath")
else:
    print ("Do with the perfumes")
# Out:
#   File "<ipython-input-3-c8728f94c46b>", line 7
#     if (<check if water will come today> ) :
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# ![Logical.png](./Images/Logical.png)

# %%
# test for membership in a sequence, such as strings, lists, or tuples
 
mulcipalityWaterDays =["Monday","Wednesday","Saturday"]
loadSheddingDays =["Monday", "Thursday", "Friday"]
 
whichDay=input("Enter the day of week")
 
if (<check if water comes today and there is no loadshedding>) :
    print ("Yaayyy, today municipal water will come and no load shedding. Will have warm water for the bath.")
else:
    print ("Do with the perfumes")

# %% [markdown]
#                                     Pratice
#
# 1. Tax calculation
# 2. Final result should be in integer
#
# |Slab Tax  |  Slab |
# |:-:|:-:|
# |0- ₹ 2,50,000|	Nil   |
# |₹ 2,50,001 - ₹ 5,00,000 | 5% |
# |₹ 5,00,000 - ₹ 7,50,000|10%|
# |₹ ₹ 7,50,000 -₹ 10,00,000 |20%|
# |Above ₹ 10,00,000 	|30%|
