# %% [markdown]
# #### Yoga and its types

# %% [markdown]
# ![Yoga.jpeg](attachment:Yoga.jpeg)

# %%
# We will map yoga to it

types = ["Hatha", "Vinyasa","Hot","Yin","Iyengar","Ashtanga","Nidra"]

# We will map yoga to it

print (<map yoga to all using lambda>)

# %% [markdown]
# #### Square all the elements in the list

# %%
first_list = [2, 4, 5]
print(first_list**2)

# %%
# Square of all the objects in the list

first_list = [2, 4, 5]

# %%
print(map(lambda x: x**2, first_list))

# %%
# Square of all the objects in the list
first_list = [2,4,5]
print(list(map(lambda x: x**2, first_list)))

# %%
def squareit(n):
    return n**2
print(list(map(squareit, first_list)))

# %%
sums_list = [3,5,9,7]
sums_list2 = (4,5,6,7)
print(<create new list by adding both>)))

# %%
firstnames = ['nikola', 'james', 'albert']
lastnames = ['tesla','watt','einstein']
proper = lambda x, y: x[0].upper()+x[1:] +' '+ y[0].upper()+y[1:]
print(list(map(proper, firstnames,lastnames)))

# %% [markdown]
# ![teaStrainer.jpeg](attachment:teaStrainer.jpeg)

# %%
#Filter and add only the values which are divisible by 3
divby3 = lambda x:  x % 3 == 0
my_list = [3,4,5,6,7,8,9]
div = <filter it>
print(list(div))

# %%
#Reduce
from functools import reduce
q  = reduce(lambda x, y: x+y, range(1,4))
print(q)

# %%
highest_marks_in_mathematics = [22,45,32,20,87,94,30]
print(reduce(<right a function with highest marks>,highest_marks_in_mathematics))

# %% [markdown]
#                                                   Practice
#
# Seven prime mininster have completed 5 years of term in office
#
# 1. "Jawaharlal Nehru",
# 2. "Indira Gandhi",
# 3. "Rajeev Gandhi",
# 4. "PV Narasimha Rao",
# 5. "AB Vajpayee",
# 6. "Manmohan Singh",
# 7. "Narendra Modi"
#
# * Put them in the list
# * Among them only two prime ministers were beard
# 1. "Manmohan Singh",
# 2. "Narendra Modi"
#
# * Filter out and show only the prime minister who were not beard.

# %% [markdown]
# ![IndiraGandhi.jpeg](attachment:IndiraGandhi.jpeg)

# %%
primeMinisterOfIndia =["Jawaharlal Nehru",
                       "Indira Gandhi",
                       "Rajeev Gandhi", 
                       "PV Narasimha Rao", 
                       "AB Vajpayee",
                       "Manmohan Singh",
                       "Narendra Modi"]

primeMinisterWithBeared =["Manmohan Singh", "Narendra Modi"]

<filter the PM>

print(list(div))
